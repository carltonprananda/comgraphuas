# %%
import tkinter as tk
from PIL import Image as PILImage
from PIL import ImageTk
from tkinter import Label
from tkinter import filedialog
from tkinter import ttk
from tkinter import Menu
import cv2
import numpy as np
 
WINDOW_NAME = "CV2 B&C Slider"
 
def on_change(effect):
    effect_choice = getattr(cv2, "COLOR_BGR2"+str(effect.split()[0]))
    edited = cv2.cvtColor(image, effect_choice)
    var1.set(effect)
    print(var1.get())
    print(effect)
def insertbutton_cb():
    #global orima, editima
    global image, edited
    global teste
 
    picpath = filedialog.askopenfilename(
        title="Select An Image",
        filetypes=(("JPG Files", "*.jpg"), ("GIF Files", "*.gif*"), ("PNG files", "*.png"), ("JPEG Files", "*.jpeg"))
    )
 
    if len(picpath) > 0:
        
        bright = 255
        contrast = 100
        
 
        image = cv2.imread(picpath)
        edited = cv2.imread(picpath)
 
        edited = np.array(edited)
        #edited = PILImage.fromarray(edited.astype('uint8'))
 
        print(picpath)
        print('Original Dimensions : ',image.shape)
        print(image)
        print(edited)
 
        scale_percent = 100 # percent of original size
        width = int(image.shape[1] * scale_percent / 100)
        height = int(image.shape[0] * scale_percent / 100)
        width2 = int(edited.shape[1] * scale_percent / 100)
        height2 = int(edited.shape[0] * scale_percent / 100)
        dim = (width, height)
        dim2 = (width2, height2)
 
        image = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
        edited = cv2.resize(edited, dim2, interpolation = cv2.INTER_AREA)
 
        image =  PILImage.fromarray(image)
        edited = PILImage.fromarray(edited)

        image = np.uint8(image)
        edited = np.uint8(edited)
  
 
        cv2.namedWindow(WINDOW_NAME)
        cv2.createTrackbar('Bright', WINDOW_NAME, 255, 2 * 255, bccb)
        cv2.createTrackbar('Contrast', WINDOW_NAME, 255, 2 * 127, bccb)
        #functionbcs(edited, 0, 0, 0)
        bccb(0, 0)
        teste = controller(image, bright, contrast)
        cv2.imshow(WINDOW_NAME, teste)
 
        #cv2.waitKey(0)
 
def savebutton_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    savepicpath = filedialog.asksaveasfilename(
        confirmoverwrite=False, defaultextension='.jpg', 
        filetypes=[("jpg files", '*.jpg'), ("png files", '*.png')],
        title="Choose filename"
    )
    saveimage =  cv2.imwrite(savepicpath, edited)
    print(saveimage)
    pass

def previewbutton_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    cv2.imshow("Preview", edited)

def savebutton2_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    edited = cv2.cvtColor(edited, cv2.COLOR_RGB2GRAY)
    savepicpath = filedialog.asksaveasfilename(
        confirmoverwrite=False, defaultextension='.jpg', 
        filetypes=[("jpg files", '*.jpg'), ("png files", '*.png')],
        title="Choose filename"
    )
    saveimage =  cv2.imwrite(savepicpath, edited)
    print(saveimage)
    pass

def previewbutton2_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    edited = cv2.cvtColor(edited, cv2.COLOR_RGB2GRAY)
    cv2.imshow("Preview", edited)
def savebutton3_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    kernel = np.array([[0.272, 0.534, 0.131],
                       [0.349, 0.686, 0.168],
                       [0.393, 0.769, 0.189]])
    
    edited = cv2.filter2D(edited, -1, kernel)
    savepicpath = filedialog.asksaveasfilename(
        confirmoverwrite=False, defaultextension='.jpg', 
        filetypes=[("jpg files", '*.jpg'), ("png files", '*.png')],
        title="Choose filename"
    )
    saveimage =  cv2.imwrite(savepicpath, edited)
    print(saveimage)
    pass
def previewbutton3_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    kernel = np.array([[0.272, 0.534, 0.131],
                       [0.349, 0.686, 0.168],
                       [0.393, 0.769, 0.189]])
    
    edited = cv2.filter2D(edited, -1, kernel)
    cv2.imshow("Preview", edited)
def savebutton4_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    kernel = np.array([[-1, -1, -1], [-1, 10, -1], [-1, -1, -1]])
    edited = cv2.filter2D(edited, -1, kernel)
    savepicpath = filedialog.asksaveasfilename(
        confirmoverwrite=False, defaultextension='.jpg', 
        filetypes=[("jpg files", '*.jpg'), ("png files", '*.png')],
        title="Choose filename"
    )
    saveimage =  cv2.imwrite(savepicpath, edited)
    print(saveimage)
    pass
def previewbutton4_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    kernel = np.array([[-1, -1, -1], [-1, 10, -1], [-1, -1, -1]])
    edited = cv2.filter2D(edited, -1, kernel)
    cv2.imshow("Preview", edited)
def savebutton5_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    
    edited = cv2.GaussianBlur(edited, (15, 15), 0)
    savepicpath = filedialog.asksaveasfilename(
        confirmoverwrite=False, defaultextension='.jpg', 
        filetypes=[("jpg files", '*.jpg'), ("png files", '*.png')],
        title="Choose filename"
    )
    saveimage =  cv2.imwrite(savepicpath, edited)
    print(saveimage)
    pass
def previewbutton5_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    
    edited = cv2.GaussianBlur(edited, (15, 15), 0)
    cv2.imshow("Preview", edited)
def savebutton6_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    
    edited = cv2.GaussianBlur(edited, (35, 35), 0)
    savepicpath = filedialog.asksaveasfilename(
        confirmoverwrite=False, defaultextension='.jpg', 
        filetypes=[("jpg files", '*.jpg'), ("png files", '*.png')],
        title="Choose filename"
    )
    saveimage =  cv2.imwrite(savepicpath, edited)
    print(saveimage)
    pass
def previewbutton6_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    
    edited = cv2.GaussianBlur(edited, (35, 35), 0)
    cv2.imshow("Preview", edited)
def savebutton7_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    
    edited = cv2.Canny(edited,100,100)
    savepicpath = filedialog.asksaveasfilename(
        confirmoverwrite=False, defaultextension='.jpg', 
        filetypes=[("jpg files", '*.jpg'), ("png files", '*.png')],
        title="Choose filename"
    )
    saveimage =  cv2.imwrite(savepicpath, edited)
    print(saveimage)
    pass
def previewbutton7_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    
    edited = cv2.Canny(edited,100,100)
    cv2.imshow("Preview", edited)
def savebutton8_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    
    edited = cv2.cvtColor(edited, cv2.COLOR_RGB2HSV)
    savepicpath = filedialog.asksaveasfilename(
        confirmoverwrite=False, defaultextension='.jpg', 
        filetypes=[("jpg files", '*.jpg'), ("png files", '*.png')],
        title="Choose filename"
    )
    saveimage =  cv2.imwrite(savepicpath, edited)
    print(saveimage)
    pass
def previewbutton8_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    edited = cv2.cvtColor(edited, cv2.COLOR_RGB2HSV)
    cv2.imshow("Preview", edited)
def savebutton9_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    
    edited = cv2.cvtColor(edited, cv2.COLOR_RGB2HLS)
    savepicpath = filedialog.asksaveasfilename(
        confirmoverwrite=False, defaultextension='.jpg', 
        filetypes=[("jpg files", '*.jpg'), ("png files", '*.png')],
        title="Choose filename"
    )
    saveimage =  cv2.imwrite(savepicpath, edited)
    print(saveimage)
    pass
def previewbutton9_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    edited = cv2.cvtColor(edited, cv2.COLOR_RGB2HLS)
    cv2.imshow("Preview", edited)
def savebutton10_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    
    edited = cv2.cvtColor(edited, cv2.COLOR_RGB2LAB)
    savepicpath = filedialog.asksaveasfilename(
        confirmoverwrite=False, defaultextension='.jpg', 
        filetypes=[("jpg files", '*.jpg'), ("png files", '*.png')],
        title="Choose filename"
    )
    saveimage =  cv2.imwrite(savepicpath, edited)
    print(saveimage)
    pass
def previewbutton10_cb():
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    edited = controller(image, bright, contrast)
    edited = cv2.cvtColor(edited, cv2.COLOR_RGB2LAB)
    cv2.imshow("Preview", edited)
    
def bccb(bright = 0, contrast=0):
    bright = cv2.getTrackbarPos('Bright', WINDOW_NAME)
    print("B : " + str(bright))
    contrast = cv2.getTrackbarPos('Contrast', WINDOW_NAME)
    print("C : " + str(contrast))
    #ksize = cv2.getTrackbarPos('Blur', WINDOW_NAME) 
    #print("Bl : " + str(ksize))
    edited = controller(image, bright, contrast)
    cv2.imshow(WINDOW_NAME, edited)
    
 
def controller(effect, bright=1, contrast=1):
    bright = int((bright - 0) * (255 - (-255)) / (510 - 0) + (-255))
 
    contrast = int((contrast - 0) * (127 - (-127)) / (254 - 0) + (-127))

    #effect = cv2.blur(effect, (ksize, ksize))
 
    if bright != 0:
        if bright > 0:
            shadow = bright
            max = 255
        else:
            shadow = 0
            max = 255 + bright
        alf = (max - shadow) / 255
        gam = shadow
 
        cal = cv2.addWeighted(effect, alf,
                              effect, 0, gam) # changed edited to effect, alfa to alf
    else:
        cal = effect
 
    if contrast != 0:
        Alf2 = float(131 * (contrast + 127)) / (127 * (131 - contrast))
        Gam2 = 127 * (1 - Alf2)
 
        # The function addWeighted calculates
        # the weighted sum of two arrays
        cal = cv2.addWeighted(cal, Alf2,
                              cal, 0, Gam2)
    #cv2.imshow('CV2 Photo Editor', effect)
    return cal

    
 
def exitbutton_cb():
    window.destroy()
    cv2.destroyAllWindows()
 
 
window = tk.Tk()
window.title('Simple Photo Editing')
mb = Menu(window)
#file manager
fm = Menu(mb, tearoff=0)
fm.add_command(label="Open", command=insertbutton_cb)
fm.add_separator()
fm.add_command(label="Exit", command=exitbutton_cb)
mb.add_cascade(label="File", menu=fm)
pm = Menu(mb, tearoff=1)
pm.add_command(label="Preview RGB", command=previewbutton_cb)
pm.add_command(label="Preview Grayscale", command=previewbutton2_cb)
pm.add_separator()
pm.add_command(label="Preview Light Sepia", command=previewbutton3_cb)
pm.add_command(label="Preview Sharpen", command=previewbutton4_cb)
pm.add_command(label="Preview LG Blur", command=previewbutton5_cb)
pm.add_command(label="Preview HG Blur", command=previewbutton6_cb)
pm.add_command(label="Preview ED", command=previewbutton7_cb)
pm.add_command(label="Preview HSV", command=previewbutton8_cb)
pm.add_command(label="Preview HLS", command=previewbutton9_cb)
pm.add_command(label="Preview LAB", command=previewbutton10_cb)
mb.add_cascade(label="Preview", menu=pm)
sm = Menu(mb, tearoff=0)
sm.add_command(label="Save RGB", command=savebutton_cb)
sm.add_command(label="Save Grayscale", command=savebutton2_cb)
sm.add_separator()
sm.add_command(label="Save Light Sepia", command=savebutton3_cb)
sm.add_command(label="Save Sharpen", command=savebutton4_cb)
sm.add_command(label="Save LG Blur", command=savebutton5_cb)
sm.add_command(label="Save HG Blur", command=savebutton6_cb)
sm.add_command(label="Save ED", command=savebutton7_cb)
sm.add_command(label="Save HSV", command=savebutton8_cb)
sm.add_command(label="Save HLS", command=savebutton9_cb)
sm.add_command(label="Save LAB", command=savebutton8_cb)
mb.add_cascade(label="Save", menu=sm)
 

 
cr = ttk.Frame(window)
canvas = tk.Canvas(cr)
scrolling = ttk.Scrollbar(cr, orient="vertical", command=canvas.yview)
 
sw = window.winfo_screenwidth()
sh = window.winfo_screenheight()
 
Frm = tk.Frame(window, height=50, width=400)
Frm.pack(anchor=tk.N)
 
label = ttk.Label(
    window, text="Simple Image Photo Editing"
)

apptitle = Label(window, 
                  text = "Simple Photo Editing by Dean and Erlangga")
apptitle.pack()

previewbutton = tk.Button(Frm, text="Open", padx=0, pady=0, command=insertbutton_cb)
previewbutton.grid(row=0, column=1)

previewbutton = tk.Button(Frm, text="Exit", padx=0, pady=0, command=exitbutton_cb)
previewbutton.grid(row=0, column=2)
 
savebutton = tk.Button(Frm, text="Save", padx=0, pady=0, command=savebutton_cb)
savebutton.grid(row=1, column=2)

previewbutton = tk.Button(Frm, text="Preview", padx=0, pady=0, command=previewbutton_cb)
previewbutton.grid(row=1, column=1)

previewgreybutton = tk.Button(Frm, text="Preview as Grayscale", padx=0, pady=0, command=previewbutton2_cb)
previewgreybutton.grid(row=2, column=1)
savegreybutton = tk.Button(Frm, text="Save as Grayscale", padx=0, pady=0, command=savebutton2_cb)
savegreybutton.grid(row=2, column=2)

previewgreybutton2 = tk.Button(Frm, text="Preview as Light Sepia", padx=0, pady=0, command=previewbutton3_cb)
previewgreybutton2.grid(row=3, column=1)
savegreybutton2 = tk.Button(Frm, text="Save as Light Sepia", padx=0, pady=0, command=savebutton3_cb)
savegreybutton2.grid(row=3, column=2)

previewgreybutton4 = tk.Button(Frm, text="Preview as Sharpen", padx=0, pady=0, command=previewbutton4_cb)
previewgreybutton4.grid(row=4, column=1)
savegreybutton4 = tk.Button(Frm, text="Save as Sharpen", padx=0, pady=0, command=savebutton4_cb)
savegreybutton4.grid(row=4, column=2)

previewgreybutton4 = tk.Button(Frm, text="Preview as LG Blur", padx=0, pady=0, command=previewbutton5_cb)
previewgreybutton4.grid(row=5, column=1)
savegreybutton4 = tk.Button(Frm, text="Save as LG Blur", padx=0, pady=0, command=savebutton5_cb)
savegreybutton4.grid(row=5, column=2)

previewgreybutton4 = tk.Button(Frm, text="Preview as HG Blur", padx=0, pady=0, command=previewbutton6_cb)
previewgreybutton4.grid(row=6, column=1)
savegreybutton4 = tk.Button(Frm, text="Save as HG Blur", padx=0, pady=0, command=savebutton6_cb)
savegreybutton4.grid(row=6, column=2)

previewgreybutton4 = tk.Button(Frm, text="Preview as ED", padx=0, pady=0, command=previewbutton7_cb)
previewgreybutton4.grid(row=7, column=1)
savegreybutton4 = tk.Button(Frm, text="Save as ED", padx=0, pady=0, command=savebutton7_cb)
savegreybutton4.grid(row=7, column=2)

previewgreybutton5 = tk.Button(Frm, text="Preview as HSV", padx=0, pady=0, command=previewbutton8_cb)
previewgreybutton5.grid(row=8, column=1)
savegreybutton5 = tk.Button(Frm, text="Save as HSV", padx=0, pady=0, command=savebutton8_cb)
savegreybutton5.grid(row=8, column=2)

previewgreybutton5 = tk.Button(Frm, text="Preview as HLS", padx=0, pady=0, command=previewbutton9_cb)
previewgreybutton5.grid(row=9, column=1)
savegreybutton5 = tk.Button(Frm, text="Save as HLS", padx=0, pady=0, command=savebutton9_cb)
savegreybutton5.grid(row=9, column=2)

previewgreybutton5 = tk.Button(Frm, text="Preview as LAB", padx=0, pady=0, command=previewbutton10_cb)
previewgreybutton5.grid(row=10, column=1)
savegreybutton5 = tk.Button(Frm, text="Save as LAB", padx=0, pady=0, command=savebutton10_cb)
savegreybutton5.grid(row=10, column=2)

orima = None
editima = None
 
window.config(menu=mb)
cv2.waitKey(0)
tk.mainloop()
